# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json 

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 619

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
city = "banmo"
query_url = url + "appid=" + api_key + "&q=" + city
weather_response = requests.get(query_url)
weather_json = weather_response.json()
print(json.dumps(weather_json, indent=4, sort_keys=True))
# Out:
# {
#     "cod": "404",
#     "message": "city not found"
# }

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
print("Beginning Data Retrieval")
print("--------------------------------")
for city in cities:
    query_url = url + "appid=" + api_key + "&q=" + city
    try:
        weather_response = requests.get(query_url)
        weather_json = weather_response.json()
        if weather_json["cod"] == "404":
            print ("City not found. Skipping......")
            cities.remove(city)
        else:
            print(f"Processing Record {cities.index(city)}  | {city}")
    except:
        print("City not found. Skipping......")
        continue
# Out:
# Beginning Data Retrieval
# --------------------------------
# Processing Record 0  | bethel
# Processing Record 1  | tasiilaq
# Processing Record 2  | cabinda
# Processing Record 3  | kodinsk
# Processing Record 4  | vostok
# Processing Record 5  | cape town
# Processing Record 6  | makokou
# Processing Record 7  | mataura
# Processing Record 8  | talbahat
# Processing Record 9  | atuona
# Processing Record 10  | ust-kuyga
# Processing Record 11  | brae
# Processing Record 12  | port alfred
# Processing Record 13  | bredasdorp
# Processing Record 14  | sao sepe
# Processing Record 15  | bud
# Processing Record 16  | altay
# Processing Record 17  | arraial do cabo
# Processing Record 18  | hilo
# Processing Record 19  | los llanos de aridane
# Processing Record 20  | rikitea
# Processing Record 21  | banganapalle
# Processing Record 22  | ilulissat
# Processing Record 23  | kaitangata
# Processing Record 24  | chokurdakh
# Processing Record 25  | clyde river
# Processing Record 26  | salalah
# Processing Record 27  | norman wells
# Processing Record 28  | salym
# Processing Record 29  | kapaa
# City not found. Skipping......
# Processing Record 31  | yellowknife
# City not found. Skipping......
# Processing Record 33  | avarua
# Processing Record 34  | rocha
# Processing Record 35  | caravelas
# Processing Record 36  | mar del plata
# Processing Record 37  | hirara
# Processing Record 38  | amapa
# Processing Record 39  | yulara
# Processing Record 40  | emba
# Processing Record 41  | ushuaia
# Processing Record 42  | mirante do paranapanema
# Processing Record 43  | yatou
# Processing Record 44  | saint-augustin
# Processing Record 45  | hovd
# Processing Record 46  | punta arenas
# Processing Record 47  | severo-kurilsk
# City not found. Skipping......
# Processing Record 49  | rio gallegos
# Processing Record 50  | santa rosa
# Processing Record 51  | hobart
# Processing Record 52  | hermanus
# Processing Record 53  | tsaratanana
# Processing Record 54  | general cepeda
# Processing Record 55  | cidreira
# Processing Record 56  | arlit
# Processing Record 57  | kapuskasing
# Processing Record 58  | saldanha
# Processing Record 59  | thompson
# Processing Record 60  | tuktoyaktuk
# City not found. Skipping......
# Processing Record 62  | airai
# Processing Record 63  | albany
# City not found. Skipping......
# Processing Record 65  | mahebourg
# City not found. Skipping......
# City not found. Skipping......
# Processing Record 68  | tiksi
# Processing Record 69  | kahta
# Processing Record 70  | faya
# Processing Record 71  | jamestown
# Processing Record 72  | ribeira grande
# Processing Record 73  | upernavik
# Processing Record 74  | vaini
# City not found. Skipping......
# Processing Record 76  | tumut
# Processing Record 77  | castro
# Processing Record 78  | quixeramobim
# Processing Record 79  | fukuma
# Processing Record 80  | roma
# Processing Record 81  | longyearbyen
# Processing Record 82  | vila franca do campo
# City not found. Skipping......
# Processing Record 84  | buy
# City not found. Skipping......
# Processing Record 86  | sven
# Processing Record 87  | soyo
# City not found. Skipping......
# Processing Record 89  | puerto ayora
# Processing Record 90  | esperance
# Processing Record 91  | cherskiy
# City not found. Skipping......
# Processing Record 93  | dryden
# Processing Record 94  | sainte-marie
# Processing Record 95  | tessalit
# Processing Record 96  | gubakha
# Processing Record 97  | georgetown
# Processing Record 98  | pemberton
# Processing Record 99  | vardo
# Processing Record 100  | sangar
# Processing Record 101  | raudeberg
# Processing Record 102  | kavieng
# Processing Record 103  | kologriv
# Processing Record 104  | alta floresta
# Processing Record 105  | arman
# Processing Record 106  | pyapon
# Processing Record 107  | glace bay
# Processing Record 108  | bambous virieux
# Processing Record 109  | rio grande
# Processing Record 110  | provideniya
# Processing Record 111  | muzhi
# Processing Record 112  | vaitape
# Processing Record 113  | grand gaube
# Processing Record 114  | phuket
# Processing Record 115  | mayo
# Processing Record 116  | hami
# Processing Record 117  | bluff
# Processing Record 118  | dikson
# Processing Record 119  | faanui
# Processing Record 120  | tadine
# Processing Record 121  | hithadhoo
# Processing Record 122  | hamilton
# Processing Record 123  | vila
# Processing Record 124  | katobu
# Processing Record 125  | khatanga
# Processing Record 126  | college
# Processing Record 127  | mount isa
# Processing Record 128  | gazojak
# City not found. Skipping......
# Processing Record 130  | torbay
# Processing Record 131  | half moon bay
# Processing Record 132  | taoudenni
# Processing Record 133  | mecca
# Processing Record 134  | paracuru
# Processing Record 135  | awjilah
# Processing Record 136  | kayerkan
# Processing Record 137  | udachnyy
# Processing Record 138  | bereda
# Processing Record 139  | luderitz
# Processing Record 140  | purpe
# Processing Record 141  | culebra
# Processing Record 142  | ballina
# Processing Record 143  | merauke
# Processing Record 144  | guaruja
# Processing Record 145  | vidim
# Processing Record 146  | aden
# Processing Record 147  | belyy yar
# Processing Record 148  | butaritari
# Processing Record 149  | ialibu
# Processing Record 150  | la belgica
# Processing Record 151  | panaba
# Processing Record 152  | the pas
# Processing Record 153  | ixtapa
# Processing Record 154  | sao joao da barra
# Processing Record 155  | shimoda
# Processing Record 156  | banyo
# Processing Record 157  | port blair
# Processing Record 158  | laguna
# City not found. Skipping......
# Processing Record 160  | cabo san lucas
# Processing Record 161  | san ramon
# Processing Record 162  | westport
# Processing Record 163  | nome
# Processing Record 164  | goroka
# Processing Record 165  | nabire
# Processing Record 166  | saint george
# Processing Record 167  | dudinka
# Processing Record 168  | vanimo
# Processing Record 169  | qaanaaq
# City not found. Skipping......
# Processing Record 171  | vao
# Processing Record 172  | fairbanks
# Processing Record 173  | carnarvon
# Processing Record 174  | mozarlandia
# City not found. Skipping......
# Processing Record 176  | dakar
# City not found. Skipping......
# Processing Record 178  | samarai
# Processing Record 179  | thinadhoo
# Processing Record 180  | naruja
# Processing Record 181  | port-cartier
# Processing Record 182  | guerrero negro
# Processing Record 183  | karratha
# Processing Record 184  | auki
# City not found. Skipping......
# Processing Record 186  | vulpeni
# Processing Record 187  | dingle
# Processing Record 188  | khurba
# Processing Record 189  | oktyabrskiy
# Processing Record 190  | malpe
# City not found. Skipping......
# Processing Record 192  | vorozhba
# Processing Record 193  | tezu
# Processing Record 194  | camacha
# Processing Record 195  | aklavik
# City not found. Skipping......
# Processing Record 197  | ambon
# Processing Record 198  | pevek
# Processing Record 199  | roald
# Processing Record 200  | port hardy
# Processing Record 201  | husavik
# Processing Record 202  | nechi
# Processing Record 203  | sinnamary
# Processing Record 204  | sulangan
# Processing Record 205  | ancud
# Processing Record 206  | chuy
# Processing Record 207  | katsuura
# Processing Record 208  | north valley
# Processing Record 209  | kaoma
# Processing Record 210  | hasaki
# Processing Record 211  | smidovich
# Processing Record 212  | pouebo
# Processing Record 213  | candolim
# Processing Record 214  | vigrestad
# City not found. Skipping......
# Processing Record 216  | talnakh
# Processing Record 217  | sao filipe
# Processing Record 218  | hobyo
# Processing Record 219  | saint-philippe
# Processing Record 220  | fortuna
# Processing Record 221  | mikhaylovka
# Processing Record 222  | pacific grove
# Processing Record 223  | varca
# Processing Record 224  | touros
# Processing Record 225  | yabrud
# Processing Record 226  | saint-georges
# Processing Record 227  | vondrozo
# Processing Record 228  | kozhevnikovo
# City not found. Skipping......
# Processing Record 230  | seoul
# Processing Record 231  | kirakira
# Processing Record 232  | aripuana
# Processing Record 233  | tolaga bay
# Processing Record 234  | biltine
# Processing Record 235  | cururupu
# Processing Record 236  | moranbah
# Processing Record 237  | narsaq
# Processing Record 238  | portland
# Processing Record 239  | progreso
# Processing Record 240  | constitucion
# City not found. Skipping......
# Processing Record 242  | kodiak
# City not found. Skipping......
# Processing Record 244  | kahului
# Processing Record 245  | nigde
# Processing Record 246  | sambava
# City not found. Skipping......
# Processing Record 248  | souillac
# Processing Record 249  | igarka
# Processing Record 250  | naryan-mar
# Processing Record 251  | artyom
# Processing Record 252  | alpena
# Processing Record 253  | werda
# Processing Record 254  | gimli
# Processing Record 255  | eyl
# Processing Record 256  | christchurch
# Processing Record 257  | onalaska
# Processing Record 258  | palana
# Processing Record 259  | burnie
# Processing Record 260  | labuhan
# Processing Record 261  | kruisfontein
# Processing Record 262  | bonavista
# City not found. Skipping......
# Processing Record 264  | tabriz
# Processing Record 265  | whitehorse
# Processing Record 266  | zhezkazgan
# Processing Record 267  | redlands
# Processing Record 268  | fengzhen
# Processing Record 269  | geraldton
# Processing Record 270  | zeya
# City not found. Skipping......
# Processing Record 272  | montepuez
# Processing Record 273  | ati
# Processing Record 274  | mae sai
# Processing Record 275  | victor harbor
# City not found. Skipping......
# Processing Record 277  | conceicao do araguaia
# Processing Record 278  | fergus falls
# Processing Record 279  | solnechnyy
# City not found. Skipping......
# Processing Record 281  | adrar
# Processing Record 282  | sorong
# Processing Record 283  | port macquarie
# Processing Record 284  | mutoko
# Processing Record 285  | pingxiang
# Processing Record 286  | miguelopolis
# Processing Record 287  | kroonstad
# Processing Record 288  | linhares
# Processing Record 289  | kilindoni
# City not found. Skipping......
# Processing Record 291  | erzin
# City not found. Skipping......
# Processing Record 293  | tchollire
# Processing Record 294  | sibi
# Processing Record 295  | sankheda
# Processing Record 296  | bathsheba
# Processing Record 297  | kavaratti
# Processing Record 298  | ulladulla
# Processing Record 299  | east london
# City not found. Skipping......
# City not found. Skipping......
# Processing Record 302  | puerto quijarro
# Processing Record 303  | muros
# Processing Record 304  | necochea
# Processing Record 305  | slave lake
# Processing Record 306  | port elizabeth
# Processing Record 307  | polyarnyy
# Processing Record 308  | kyzyl-suu
# Processing Record 309  | nanortalik
# Processing Record 310  | puri
# Processing Record 311  | minot
# Processing Record 312  | macamic
# Processing Record 313  | jiwani
# Processing Record 314  | haysville
# City not found. Skipping......
# Processing Record 316  | yabelo
# Processing Record 317  | avera
# Processing Record 318  | payo
# Processing Record 319  | mehamn
# Processing Record 320  | bohmte
# Processing Record 321  | sarai
# Processing Record 322  | turukhansk
# City not found. Skipping......
# Processing Record 324  | victoria
# Processing Record 325  | lorengau
# Processing Record 326  | yuzhne
# Processing Record 327  | soe
# Processing Record 328  | lata
# Processing Record 329  | pangai
# Processing Record 330  | paita
# Processing Record 331  | rincon
# Processing Record 332  | lianzhou
# Processing Record 333  | darhan
# Processing Record 334  | vila velha
# Processing Record 335  | yeppoon
# City not found. Skipping......
# City not found. Skipping......
# Processing Record 338  | sujangarh
# Processing Record 339  | mount gambier
# Processing Record 340  | trujillo
# Processing Record 341  | wattegama
# Processing Record 342  | millbrook
# City not found. Skipping......
# Processing Record 344  | nouadhibou
# Processing Record 345  | neiafu
# Processing Record 346  | baykit
# Processing Record 347  | boyolangu
# Processing Record 348  | teguldet
# Processing Record 349  | orange cove
# Processing Record 350  | nisia floresta
# City not found. Skipping......
# Processing Record 352  | general roca
# Processing Record 353  | charters towers
# Processing Record 354  | alihe
# Processing Record 355  | sabha
# Processing Record 356  | eureka
# Processing Record 357  | burgos
# Processing Record 358  | rawson
# Processing Record 359  | iquique
# Processing Record 360  | kananga
# Processing Record 361  | pringsewu
# Processing Record 362  | sakaiminato
# Processing Record 363  | erdenet
# Processing Record 364  | yuksekova
# Processing Record 365  | grindavik
# Processing Record 366  | pitimbu
# Processing Record 367  | bontang
# Processing Record 368  | shalakusha
# Processing Record 369  | teguise
# Processing Record 370  | biskamzha
# Processing Record 371  | horodnytsya
# Processing Record 372  | storvorde
# Processing Record 373  | zheleznodorozhnyy
# Processing Record 374  | rahimatpur
# Processing Record 375  | biritiba-mirim
# Processing Record 376  | machiques
# Processing Record 377  | jiangyou
# Processing Record 378  | mackay
# City not found. Skipping......
# Processing Record 380  | maceio
# Processing Record 381  | campagna
# Processing Record 382  | malanje
# Processing Record 383  | saint anthony
# City not found. Skipping......
# Processing Record 385  | bridlington
# Processing Record 386  | santa isabel do rio negro
# Processing Record 387  | kamaishi
# Processing Record 388  | zhigansk
# Processing Record 389  | ambanja
# Processing Record 390  | palafrugell
# Processing Record 391  | tamiahua
# Processing Record 392  | juegang
# Processing Record 393  | srednekolymsk
# Processing Record 394  | orange walk
# Processing Record 395  | margate
# Processing Record 396  | nokaneng
# City not found. Skipping......
# Processing Record 398  | coxcatlan
# Processing Record 399  | boshnyakovo
# Processing Record 400  | shingu
# Processing Record 401  | saint-francois
# Processing Record 402  | itacarambi
# Processing Record 403  | pedro ii
# Processing Record 404  | la ronge
# Processing Record 405  | mtimbira
# Processing Record 406  | buraydah
# Processing Record 407  | pisco
# Processing Record 408  | klaksvik
# Processing Record 409  | ciudad bolivar
# Processing Record 410  | fare
# City not found. Skipping......
# Processing Record 412  | jipijapa
# Processing Record 413  | mayumba
# Processing Record 414  | marquette
# Processing Record 415  | ayagoz
# City not found. Skipping......
# Processing Record 417  | wagar
# Processing Record 418  | kolokani
# Processing Record 419  | grand forks
# Processing Record 420  | warangal
# Processing Record 421  | santa cruz de la palma
# Processing Record 422  | birin
# Processing Record 423  | romny
# Processing Record 424  | baghmara
# Processing Record 425  | san cristobal
# Processing Record 426  | paamiut
# City not found. Skipping......
# Processing Record 428  | naze
# Processing Record 429  | wonthaggi
# Processing Record 430  | flin flon
# Processing Record 431  | blackfoot
# Processing Record 432  | kongoussi
# Processing Record 433  | paramonga
# Processing Record 434  | kaeo
# Processing Record 435  | mingshui
# Processing Record 436  | tacuati
# Processing Record 437  | jalu
# Processing Record 438  | namibe
# Processing Record 439  | gravdal
# Processing Record 440  | senador jose porfirio
# Processing Record 441  | le port
# Processing Record 442  | sao jose da coroa grande
# Processing Record 443  | kendari
# Processing Record 444  | rawlins
# Processing Record 445  | palauig
# Processing Record 446  | cockburn town
# City not found. Skipping......
# Processing Record 448  | san patricio
# Processing Record 449  | henties bay
# Processing Record 450  | bandrele
# Processing Record 451  | cermik
# Processing Record 452  | la plata
# Processing Record 453  | champoton
# Processing Record 454  | aksu
# Processing Record 455  | atar
# Processing Record 456  | nyurba
# Processing Record 457  | cayenne
# Processing Record 458  | iwanai
# Processing Record 459  | abu zabad
# Processing Record 460  | lekoni
# Processing Record 461  | chicama
# Processing Record 462  | belmonte
# Processing Record 463  | huntsville
# Processing Record 464  | aguas vermelhas
# Processing Record 465  | kingisepp
# Processing Record 466  | calama
# Processing Record 467  | west plains
# Processing Record 468  | agadez
# Processing Record 469  | richards bay
# Processing Record 470  | egvekinot
# Processing Record 471  | preobrazheniye
# City not found. Skipping......
# Processing Record 473  | port antonio
# Processing Record 474  | namatanai
# Processing Record 475  | flinders
# Processing Record 476  | keffi
# Processing Record 477  | nantucket
# Processing Record 478  | revda
# Processing Record 479  | bayir
# Processing Record 480  | businga
# Processing Record 481  | porto novo
# Processing Record 482  | rovaniemi
# Processing Record 483  | okhotsk
# Processing Record 484  | santa cruz
# Processing Record 485  | nikolskoye
# Processing Record 486  | coahuayana
# Processing Record 487  | toribio
# Processing Record 488  | norilsk
# Processing Record 489  | sault sainte marie
# City not found. Skipping......
# Processing Record 491  | san pedro de lloc
# Processing Record 492  | qeshm
# Processing Record 493  | kununurra
# Processing Record 494  | iralaya
# Processing Record 495  | khani
# Processing Record 496  | iqaluit
# Processing Record 497  | san matias
# Processing Record 498  | yafran
# Processing Record 499  | loveland
# Processing Record 500  | leh
# City not found. Skipping......
# Processing Record 502  | khasan
# Processing Record 503  | wajima
# Processing Record 504  | ulverstone
# Processing Record 505  | leningradskiy
# Processing Record 506  | acari
# Processing Record 507  | luganville
# City not found. Skipping......
# Processing Record 509  | port pirie
# City not found. Skipping......
# Processing Record 511  | hambantota
# Processing Record 512  | san francisco
# Processing Record 513  | buzmeyin
# Processing Record 514  | songjianghe
# Processing Record 515  | tabou
# Processing Record 516  | ayorou
# Processing Record 517  | ust-nera
# City not found. Skipping......
# Processing Record 519  | tequila
# Processing Record 520  | caete
# Processing Record 521  | dunedin
# City not found. Skipping......
# Processing Record 523  | hirado
# Processing Record 524  | luebo
# Processing Record 525  | haldia
# City not found. Skipping......
# Processing Record 527  | okato
# Processing Record 528  | vanavara
# Processing Record 529  | custodia
# Processing Record 530  | bolshaya glushitsa
# Processing Record 531  | quatre cocos
# Processing Record 532  | nara
# Processing Record 533  | lagoa
# City not found. Skipping......
# Processing Record 535  | north platte
# City not found. Skipping......
# Processing Record 537  | maragogi
# City not found. Skipping......
# Processing Record 539  | yar-sale
# Processing Record 540  | port augusta
# Processing Record 541  | pagegiai
# Processing Record 542  | bondo
# Processing Record 543  | sur
# Processing Record 544  | varkkallai
# Processing Record 545  | rosetta
# Processing Record 546  | terrace
# Processing Record 547  | semnan
# Processing Record 548  | tazmalt
# Processing Record 549  | valdivia
# Processing Record 550  | walvis bay
# Processing Record 551  | natal
# Processing Record 552  | guiratinga
# Processing Record 553  | san quintin
# Processing Record 554  | tautira
# Processing Record 555  | panama city
# Processing Record 556  | san juan nepomuceno
# Processing Record 557  | scarborough
# Processing Record 558  | tanout
# Processing Record 559  | snasa
# City not found. Skipping......

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# cities = [city.capitalize() for city in cities]
city_df = pd.DataFrame(np.array(cities))
city_df.columns =["City"] 
city_df['Cloudiness'] = ""
city_df['Country'] = ""
city_df['Date'] = ""
city_df['Humidity'] = ""
city_df['Lat'] = ""
city_df['Lng'] = ""
city_df['Max Temp'] = ""
city_df['Wind Speed'] = ""
city_df.head()
# Out:
#        City Cloudiness Country Date Humidity Lat Lng Max Temp Wind Speed
# 0    bethel
# 1  tasiilaq
# 2   cabinda
# 3   kodinsk
# 4    vostok

# %%
for index,row in city_df.iterrows():
    city = row['City']
    query_url = url + "appid=" + api_key + "&q=" + city
    try:
        make_request = requests.get(query_url)
        json_response = make_request.json()
        city_df.loc[index, "Cloudiness"] = json_response["clouds"]["all"]
        city_df.loc[index, "Country"] = json_response["sys"]["country"]
        city_df.loc[index, "Date"] = json_response["dt"]
        city_df.loc[index, "Humidity"] = json_response["main"]["humidity"]
        city_df.loc[index, "Lat"] = json_response["coord"]["lat"]
        city_df.loc[index, "Lng"] = json_response["coord"]["lon"]
        city_df.loc[index, "Max Temp"] = json_response["main"]["temp_max"]
        city_df.loc[index, "Wind Speed"] = json_response["wind"]["speed"]
    except:
        continue

city_df.head()
# Out:
#        City Cloudiness Country        Date Humidity    Lat     Lng Max Temp  \
# 0    bethel         75      US  1553709360       86  60.79 -161.76   273.15
# 1  tasiilaq         40      GL  1553709000       57  65.61  -37.64   268.15
# 2   cabinda         40      AO  1553709600       83  -5.56   12.19   302.15
# 3   kodinsk          0      RU  1553712746       71   58.6   99.18  262.358
# 4    vostok         64      RU  1553712992       57  46.45  135.83  262.258
#
#   Wind Speed
# 0        3.1
# 1        0.5
# 2        3.1
# 3       1.06
# 4       1.56

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
print(city_df.count())
print(city_df.dtypes)
# Out:
# City          561
# Cloudiness    561
# Country       561
# Date          561
# Humidity      561
# Lat           561
# Lng           561
# Max Temp      561
# Wind Speed    561
# dtype: int64
# City          object
# Cloudiness    object
# Country       object
# Date          object
# Humidity      object
# Lat           object
# Lng           object
# Max Temp      object
# Wind Speed    object
# dtype: object

# %%
cols = ['Cloudiness', 'Humidity', 'Lat','Lng','Max Temp','Wind Speed']
city_df[cols] = city_df[cols].apply(pd.to_numeric, errors='coerce', axis=1)
city_df.dtypes
city_df["Date"] = pd.to_datetime(city_df["Date"]).apply(lambda x: x.date())

# %%
ax = city_df.plot(kind="scatter", x="Lat", y="Max Temp", marker="o", color="blue", edgecolors="black", grid=True,  title="City Latitude vs Max Temperature")
ax.set_xlabel("Latitude")
ax.set_ylabel("Max Temperature (F)")
# Out:
# Text(0, 0.5, 'Max Temperature (F)')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
ax = city_df.plot(kind="scatter", x="Lat", y="Humidity", ylim = (0,110), marker="o", color="blue", edgecolors="black", grid=True,  title=("City Latitude vs Humidity"))
city_df.loc[city_df["Humidity"] > 250]
ax.set_xlabel("Latitude")
ax.set_ylabel("Humidity(%)")
# Out:
# Text(0, 0.5, 'Humidity(%)')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
ax = city_df.plot(kind="scatter", x="Lat", y="Cloudiness", marker="o", color="blue", edgecolors="black", grid=True,  title=("City Latitude vs Cloudiness"))
ax.set_xlabel("Latitude")
ax.set_ylabel("Cloudiness(%)")
# Out:
# Text(0, 0.5, 'Cloudiness(%)')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
ax = city_df.plot(kind="scatter", x="Lat", y="Wind Speed", marker="o", color="blue", edgecolors="black", grid=True,  title=("City Latitude vs Wind Speed"))
ax.set_xlabel("Latitude")
ax.set_ylabel("Wind Speed (mph)")
# Out:
# Text(0, 0.5, 'Wind Speed (mph)')
