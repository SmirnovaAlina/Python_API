# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json 

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 626

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
city = "banmo"
query_url = url + "appid=" + api_key + "&q=" + city
weather_response = requests.get(query_url)
weather_json = weather_response.json()
print(json.dumps(weather_json, indent=4, sort_keys=True))
# Out:
# {
#     "cod": "404",
#     "message": "city not found"
# }

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
print("Beginning Data Retrieval")
print("--------------------------------")
for city in cities:
    query_url = url + "appid=" + api_key + "&q=" + city
    try:
        weather_response = requests.get(query_url)
        weather_json = weather_response.json()
        print(f"Processing Record {cities.index(city)}  | {city}")
    except:
        print("City not found. Skipping......")
        continue
# Out:
# Beginning Data Retrieval
# --------------------------------
# Processing Record 0  | yellowknife
# Processing Record 1  | mataura
# Processing Record 2  | hare bay
# Processing Record 3  | cockburn town
# Processing Record 4  | mar del plata
# Processing Record 5  | upernavik
# Processing Record 6  | hermanus
# Processing Record 7  | los llanos de aridane
# Processing Record 8  | tabory
# Processing Record 9  | albany
# Processing Record 10  | atuona
# Processing Record 11  | tsihombe
# Processing Record 12  | asfi
# Processing Record 13  | punta arenas
# Processing Record 14  | georgetown
# Processing Record 15  | vanimo
# Processing Record 16  | churapcha
# Processing Record 17  | bredasdorp
# Processing Record 18  | kuche
# Processing Record 19  | cape canaveral
# Processing Record 20  | esil
# Processing Record 21  | kintampo
# Processing Record 22  | saldanha
# Processing Record 23  | moerai
# Processing Record 24  | iskateley
# Processing Record 25  | carnarvon
# Processing Record 26  | rikitea
# Processing Record 27  | norman wells
# Processing Record 28  | hithadhoo
# Processing Record 29  | soyo
# Processing Record 30  | waipawa
# Processing Record 31  | kurchum
# Processing Record 32  | busselton
# Processing Record 33  | tumannyy
# Processing Record 34  | klaksvik
# Processing Record 35  | lima
# Processing Record 36  | tiksi
# Processing Record 37  | dhidhdhoo
# Processing Record 38  | kodiak
# Processing Record 39  | sola
# Processing Record 40  | illoqqortoormiut
# Processing Record 41  | namatanai
# Processing Record 42  | borogontsy
# Processing Record 43  | aberdeen
# Processing Record 44  | nishihara
# Processing Record 45  | barreirinhas
# Processing Record 46  | mayumba
# Processing Record 47  | shingu
# Processing Record 48  | nanortalik
# Processing Record 49  | flinders
# Processing Record 50  | makakilo city
# Processing Record 51  | grand river south east
# Processing Record 52  | hami
# Processing Record 53  | tasiilaq
# Processing Record 54  | hilo
# Processing Record 55  | tuatapere
# Processing Record 56  | nikolskoye
# Processing Record 57  | cape town
# Processing Record 58  | puerto ayora
# Processing Record 59  | kargala
# Processing Record 60  | ushuaia
# Processing Record 61  | saleaula
# Processing Record 62  | bonthe
# Processing Record 63  | pevek
# Processing Record 64  | castro
# Processing Record 65  | pochutla
# Processing Record 66  | portland
# Processing Record 67  | kaitangata
# Processing Record 68  | vila velha
# Processing Record 69  | svetlogorsk
# Processing Record 70  | samusu
# Processing Record 71  | vaini
# Processing Record 72  | kapaa
# Processing Record 73  | acapulco
# Processing Record 74  | severo-kurilsk
# Processing Record 75  | dongsheng
# Processing Record 76  | jamestown
# Processing Record 77  | barrow
# Processing Record 78  | price
# Processing Record 79  | la orilla
# Processing Record 80  | sunrise manor
# Processing Record 81  | tessaoua
# Processing Record 82  | leshukonskoye
# Processing Record 83  | kuybysheve
# Processing Record 84  | lang suan
# Processing Record 85  | petropavlovsk-kamchatskiy
# Processing Record 86  | kieta
# Processing Record 87  | vila franca do campo
# Processing Record 88  | port alfred
# Processing Record 89  | new norfolk
# Processing Record 90  | ijaki
# Processing Record 91  | beyneu
# Processing Record 92  | tromso
# Processing Record 93  | victoria
# Processing Record 94  | barentsburg
# Processing Record 95  | dingle
# Processing Record 96  | loreto
# Processing Record 97  | whitehorse
# Processing Record 98  | hobart
# Processing Record 99  | camacha
# Processing Record 100  | fairlie
# Processing Record 101  | saint-philippe
# Processing Record 102  | pozoblanco
# Processing Record 103  | lebu
# Processing Record 104  | cabo san lucas
# Processing Record 105  | constitucion
# Processing Record 106  | san jose
# Processing Record 107  | bilibino
# Processing Record 108  | mrirt
# Processing Record 109  | coquimbo
# Processing Record 110  | aklavik
# Processing Record 111  | ichinohe
# Processing Record 112  | vardo
# Processing Record 113  | east london
# Processing Record 114  | saint george
# Processing Record 115  | anadyr
# Processing Record 116  | ambilobe
# Processing Record 117  | thompson
# Processing Record 118  | mandurah
# Processing Record 119  | chokurdakh
# Processing Record 120  | avarua
# Processing Record 121  | tasbuget
# Processing Record 122  | hasaki
# Processing Record 123  | butaritari
# Processing Record 124  | chuy
# Processing Record 125  | tabuk
# Processing Record 126  | vao
# Processing Record 127  | toliary
# Processing Record 128  | curvelo
# Processing Record 129  | turukhansk
# Processing Record 130  | nizhniy tsasuchey
# Processing Record 131  | koumac
# Processing Record 132  | fortuna
# Processing Record 133  | balkhash
# Processing Record 134  | tessalit
# Processing Record 135  | mackenzie
# Processing Record 136  | port elizabeth
# Processing Record 137  | ponta do sol
# Processing Record 138  | hamilton
# Processing Record 139  | richards bay
# Processing Record 140  | carballo
# Processing Record 141  | paucartambo
# Processing Record 142  | palmer
# Processing Record 143  | hobyo
# Processing Record 144  | kaihua
# Processing Record 145  | mashhad
# Processing Record 146  | boone
# Processing Record 147  | toba
# Processing Record 148  | esperance
# Processing Record 149  | uchaly
# Processing Record 150  | bambous virieux
# Processing Record 151  | ketchikan
# Processing Record 152  | braganca
# Processing Record 153  | provideniya
# Processing Record 154  | cherskiy
# Processing Record 155  | luanda
# Processing Record 156  | myitkyina
# Processing Record 157  | valdemarpils
# Processing Record 158  | nara
# Processing Record 159  | tilichiki
# Processing Record 160  | zamora
# Processing Record 161  | tual
# Processing Record 162  | porto novo
# Processing Record 163  | oranjemund
# Processing Record 164  | puerto princesa
# Processing Record 165  | sao joao da barra
# Processing Record 166  | anuchino
# Processing Record 167  | ruatoria
# Processing Record 168  | bereda
# Processing Record 169  | killorglin
# Processing Record 170  | souillac
# Processing Record 171  | guerrero negro
# Processing Record 172  | chiang khong
# Processing Record 173  | lukovetskiy
# Processing Record 174  | tazovskiy
# Processing Record 175  | berlevag
# Processing Record 176  | taolanaro
# Processing Record 177  | koutiala
# Processing Record 178  | lorengau
# Processing Record 179  | port blair
# Processing Record 180  | mecca
# Processing Record 181  | kapit
# Processing Record 182  | leiyang
# Processing Record 183  | tacna
# Processing Record 184  | jalu
# Processing Record 185  | vaitupu
# Processing Record 186  | ous
# Processing Record 187  | bengkulu
# Processing Record 188  | dukat
# Processing Record 189  | blagoyevo
# Processing Record 190  | tuktoyaktuk
# Processing Record 191  | paonta sahib
# Processing Record 192  | torbay
# Processing Record 193  | kalmar
# Processing Record 194  | sentyabrskiy
# Processing Record 195  | ribeira grande
# Processing Record 196  | palana
# Processing Record 197  | howard springs
# Processing Record 198  | erenhot
# Processing Record 199  | hofn
# Processing Record 200  | tura
# Processing Record 201  | mangan
# Processing Record 202  | la ronge
# Processing Record 203  | kupino
# Processing Record 204  | ukiah
# Processing Record 205  | sao felix do xingu
# Processing Record 206  | neiafu
# Processing Record 207  | lolua
# Processing Record 208  | dikson
# Processing Record 209  | turayf
# Processing Record 210  | gamba
# Processing Record 211  | charters towers
# Processing Record 212  | fairbanks
# Processing Record 213  | amderma
# Processing Record 214  | puerto ayacucho
# Processing Record 215  | beisfjord
# Processing Record 216  | alice springs
# Processing Record 217  | lagoa
# Processing Record 218  | te anau
# Processing Record 219  | cambrils
# Processing Record 220  | namibe
# Processing Record 221  | launceston
# Processing Record 222  | huoqiu
# Processing Record 223  | bluff
# Processing Record 224  | donskoye
# Processing Record 225  | isangel
# Processing Record 226  | longyearbyen
# Processing Record 227  | arraial do cabo
# Processing Record 228  | luderitz
# Processing Record 229  | ilulissat
# Processing Record 230  | hambantota
# Processing Record 231  | kenai
# Processing Record 232  | ostrovnoy
# Processing Record 233  | kavieng
# Processing Record 234  | gat
# Processing Record 235  | maragogi
# Processing Record 236  | katsuura
# Processing Record 237  | hailar
# Processing Record 238  | bethel
# Processing Record 239  | guajara-mirim
# Processing Record 240  | juneau
# Processing Record 241  | nome
# Processing Record 242  | komsomolskiy
# Processing Record 243  | caravelas
# Processing Record 244  | casablanca
# Processing Record 245  | katherine
# Processing Record 246  | kulotino
# Processing Record 247  | oksfjord
# Processing Record 248  | nizhneyansk
# Processing Record 249  | saint pete beach
# Processing Record 250  | san cristobal
# Processing Record 251  | galgani
# Processing Record 252  | waddan
# Processing Record 253  | nenjiang
# Processing Record 254  | goryachegorsk
# Processing Record 255  | ahipara
# Processing Record 256  | matay
# Processing Record 257  | halifax
# Processing Record 258  | lodja
# Processing Record 259  | boquira
# Processing Record 260  | maldonado
# Processing Record 261  | mandalgovi
# Processing Record 262  | nemuro
# Processing Record 263  | bubaque
# Processing Record 264  | kahului
# Processing Record 265  | talnakh
# Processing Record 266  | sao filipe
# Processing Record 267  | kidal
# Processing Record 268  | canutama
# Processing Record 269  | doctor arroyo
# Processing Record 270  | qaqortoq
# Processing Record 271  | saskylakh
# Processing Record 272  | chara
# Processing Record 273  | bongandanga
# Processing Record 274  | bara
# Processing Record 275  | calvinia
# Processing Record 276  | san jeronimo
# Processing Record 277  | gwadar
# Processing Record 278  | henderson
# Processing Record 279  | betong
# Processing Record 280  | ust-nera
# Processing Record 281  | bur gabo
# Processing Record 282  | airai
# Processing Record 283  | axim
# Processing Record 284  | bafoulabe
# Processing Record 285  | port hardy
# Processing Record 286  | mount gambier
# Processing Record 287  | huntsville
# Processing Record 288  | iqaluit
# Processing Record 289  | puerto escondido
# Processing Record 290  | korla
# Processing Record 291  | ojinaga
# Processing Record 292  | ust-kulom
# Processing Record 293  | mayya
# Processing Record 294  | nago
# Processing Record 295  | portsmouth
# Processing Record 296  | naze
# Processing Record 297  | ranong
# Processing Record 298  | qaanaaq
# Processing Record 299  | attawapiskat
# Processing Record 300  | broome
# Processing Record 301  | bolungarvik
# Processing Record 302  | baker city
# Processing Record 303  | labuhan
# Processing Record 304  | cabaiguan
# Processing Record 305  | oistins
# Processing Record 306  | gravdal
# Processing Record 307  | mabaruma
# Processing Record 308  | chegdomyn
# Processing Record 309  | itoman
# Processing Record 310  | ramsar
# Processing Record 311  | rancho palos verdes
# Processing Record 312  | geraldton
# Processing Record 313  | lumeje
# Processing Record 314  | kuruman
# Processing Record 315  | lodwar
# Processing Record 316  | gustrow
# Processing Record 317  | talara
# Processing Record 318  | otacilio costa
# Processing Record 319  | orangeburg
# Processing Record 320  | nam som
# Processing Record 321  | tome-acu
# Processing Record 322  | villa de reyes
# Processing Record 323  | alofi
# Processing Record 324  | gizo
# Processing Record 325  | haines junction
# Processing Record 326  | touros
# Processing Record 327  | umm lajj
# Processing Record 328  | belaya gora
# Processing Record 329  | pisco
# Processing Record 330  | eureka
# Processing Record 331  | villafranca di verona
# Processing Record 332  | huilong
# Processing Record 333  | igarka
# Processing Record 334  | quartucciu
# Processing Record 335  | meulaboh
# Processing Record 336  | atasu
# Processing Record 337  | wonthaggi
# Processing Record 338  | port lincoln
# Processing Record 339  | tecoanapa
# Processing Record 340  | yar-sale
# Processing Record 341  | sorland
# Processing Record 342  | zhanaozen
# Processing Record 343  | lucapa
# Processing Record 344  | itarema
# Processing Record 345  | orlik
# Processing Record 346  | tabiauea
# Processing Record 347  | jian
# Processing Record 348  | ende
# Processing Record 349  | lokosovo
# Processing Record 350  | palabuhanratu
# Processing Record 351  | toguchin
# Processing Record 352  | mokhotlong
# Processing Record 353  | mys shmidta
# Processing Record 354  | margate
# Processing Record 355  | urumqi
# Processing Record 356  | khawhai
# Processing Record 357  | kembe
# Processing Record 358  | sarakhs
# Processing Record 359  | khatanga
# Processing Record 360  | nizwa
# Processing Record 361  | belushya guba
# Processing Record 362  | ashington
# Processing Record 363  | mount isa
# Processing Record 364  | guiyang
# Processing Record 365  | carndonagh
# Processing Record 366  | male
# Processing Record 367  | takoradi
# Processing Record 368  | abu dhabi
# Processing Record 369  | kyaukse
# Processing Record 370  | southampton
# Processing Record 371  | edson
# Processing Record 372  | uwayl
# Processing Record 373  | requena
# Processing Record 374  | tevaitoa
# Processing Record 375  | dubrovnik
# Processing Record 376  | tottenham
# Processing Record 377  | cacequi
# Processing Record 378  | burkhala
# Processing Record 379  | cayenne
# Processing Record 380  | sur
# Processing Record 381  | antalaha
# Processing Record 382  | dunedin
# Processing Record 383  | nayoro
# Processing Record 384  | ciudad bolivar
# Processing Record 385  | buraydah
# Processing Record 386  | zolotinka
# Processing Record 387  | ituni
# Processing Record 388  | menomonie
# Processing Record 389  | la trinitaria
# Processing Record 390  | paita
# Processing Record 391  | pagudpud
# Processing Record 392  | jiayuguan
# Processing Record 393  | bilma
# Processing Record 394  | keti bandar
# Processing Record 395  | atambua
# Processing Record 396  | pontianak
# Processing Record 397  | egvekinot
# Processing Record 398  | uthal
# Processing Record 399  | mokhsogollokh
# Processing Record 400  | bonavista
# Processing Record 401  | krasnoselkup
# Processing Record 402  | quepos
# Processing Record 403  | kruisfontein
# Processing Record 404  | coxim
# Processing Record 405  | nevsehir
# Processing Record 406  | clyde river
# Processing Record 407  | ormara
# Processing Record 408  | shelburne
# Processing Record 409  | rocha
# Processing Record 410  | marcona
# Processing Record 411  | sorong
# Processing Record 412  | port-cartier
# Processing Record 413  | tigil
# Processing Record 414  | sibolga
# Processing Record 415  | pimenta bueno
# Processing Record 416  | omboue
# Processing Record 417  | beringovskiy
# Processing Record 418  | karaton
# Processing Record 419  | ust-maya
# Processing Record 420  | quata
# Processing Record 421  | brae
# Processing Record 422  | maroantsetra
# Processing Record 423  | vitimskiy
# Processing Record 424  | novoorsk
# Processing Record 425  | sorada
# Processing Record 426  | beloha
# Processing Record 427  | lavrentiya
# Processing Record 428  | porbandar
# Processing Record 429  | wanning
# Processing Record 430  | seduva
# Processing Record 431  | laguna
# Processing Record 432  | ust-ishim
# Processing Record 433  | sesheke
# Processing Record 434  | mareeba
# Processing Record 435  | black river
# Processing Record 436  | asau
# Processing Record 437  | mehamn
# Processing Record 438  | utiroa
# Processing Record 439  | kodar
# Processing Record 440  | mahebourg
# Processing Record 441  | saint-denis
# Processing Record 442  | tunxi
# Processing Record 443  | syke
# Processing Record 444  | lufilufi
# Processing Record 445  | college
# Processing Record 446  | port augusta
# Processing Record 447  | pangody
# Processing Record 448  | aksarka
# Processing Record 449  | athabasca
# Processing Record 450  | sobolevo
# Processing Record 451  | diapaga
# Processing Record 452  | san quintin
# Processing Record 453  | kedrovyy
# Processing Record 454  | phuket
# Processing Record 455  | buala
# Processing Record 456  | cazones
# Processing Record 457  | el wasta
# Processing Record 458  | deputatskiy
# Processing Record 459  | tahoua
# Processing Record 460  | terrace
# Processing Record 461  | umzimvubu
# Processing Record 462  | muzquiz
# Processing Record 463  | kungurtug
# Processing Record 464  | chiredzi
# Processing Record 465  | duba-yurt
# Processing Record 466  | kununurra
# Processing Record 467  | cody
# Processing Record 468  | mangrol
# Processing Record 469  | bjornevatn
# Processing Record 470  | oxford
# Processing Record 471  | floriano
# Processing Record 472  | dumalinao
# Processing Record 473  | ixtapa
# Processing Record 474  | palu
# Processing Record 475  | vostok
# Processing Record 476  | port hedland
# Processing Record 477  | wilkie
# Processing Record 478  | hongjiang
# Processing Record 479  | zhanatas
# Processing Record 480  | khorixas
# Processing Record 481  | nata
# Processing Record 482  | limanowa
# Processing Record 483  | biltine
# Processing Record 484  | nuuk
# Processing Record 485  | ypsonas
# Processing Record 486  | paracuru
# Processing Record 487  | russell
# Processing Record 488  | jaicos
# Processing Record 489  | sinnamary
# Processing Record 490  | ha tinh
# Processing Record 491  | farim
# Processing Record 492  | ozernovskiy
# Processing Record 493  | storforshei
# Processing Record 494  | abu kamal
# Processing Record 495  | san carlos
# Processing Record 496  | kuala krai
# Processing Record 497  | viedma
# Processing Record 498  | perth
# Processing Record 499  | ayolas
# Processing Record 500  | kushmurun
# Processing Record 501  | dutlwe
# Processing Record 502  | meihekou
# Processing Record 503  | varhaug
# Processing Record 504  | narsaq
# Processing Record 505  | nyurba
# Processing Record 506  | samarai
# Processing Record 507  | beboto
# Processing Record 508  | le port
# Processing Record 509  | milledgeville
# Processing Record 510  | karlshamn
# Processing Record 511  | palencia
# Processing Record 512  | kousseri
# Processing Record 513  | cidreira
# Processing Record 514  | alabaster
# Processing Record 515  | marystown
# Processing Record 516  | jiangyou
# Processing Record 517  | coahuayana
# Processing Record 518  | miles city
# Processing Record 519  | elk
# Processing Record 520  | ayorou
# Processing Record 521  | comodoro rivadavia
# Processing Record 522  | cortez
# Processing Record 523  | lasa
# Processing Record 524  | houston
# Processing Record 525  | pavilosta
# Processing Record 526  | san miguel
# Processing Record 527  | matagami
# Processing Record 528  | saint anthony
# Processing Record 529  | faya
# Processing Record 530  | jardim
# Processing Record 531  | doctor pedro p. pena
# Processing Record 532  | padang
# Processing Record 533  | yichang
# Processing Record 534  | salalah
# Processing Record 535  | pacific grove
# Processing Record 536  | cedar city
# Processing Record 537  | tshikapa
# Processing Record 538  | thermi
# Processing Record 539  | tartagal
# Processing Record 540  | gazli
# Processing Record 541  | katangli
# Processing Record 542  | antofagasta
# Processing Record 543  | karratha
# Processing Record 544  | xichang
# Processing Record 545  | cururupu
# Processing Record 546  | presidente dutra
# Processing Record 547  | lompoc
# Processing Record 548  | walvis bay
# Processing Record 549  | bani
# Processing Record 550  | navirai
# Processing Record 551  | kimbe
# Processing Record 552  | port shepstone
# Processing Record 553  | faanui
# Processing Record 554  | khuzhir
# Processing Record 555  | srednekolymsk
# Processing Record 556  | riorges
# Processing Record 557  | chelbasskaya
# Processing Record 558  | leningradskiy
# Processing Record 559  | hillsborough
# Processing Record 560  | saint-georges
# Processing Record 561  | burnie
# Processing Record 562  | erzin
# Processing Record 563  | porto walter
# Processing Record 564  | traralgon
# Processing Record 565  | amahai
# Processing Record 566  | half moon bay
# Processing Record 567  | tarakan
# Processing Record 568  | alyangula
# Processing Record 569  | khani
# Processing Record 570  | baguanos
# Processing Record 571  | anori
# Processing Record 572  | maniitsoq
# Processing Record 573  | dahuk
# Processing Record 574  | ust-barguzin
# Processing Record 575  | san antonio
# Processing Record 576  | lata
# Processing Record 577  | marovoay
# Processing Record 578  | normandin
# Processing Record 579  | apac
# Processing Record 580  | uhlove
# Processing Record 581  | sitka
# Processing Record 582  | mayor pablo lagerenza
# Processing Record 583  | kyzyl-mazhalyk
# Processing Record 584  | hue
# Processing Record 585  | kosh-agach
# Processing Record 586  | sayyan
# Processing Record 587  | san vicente
# Processing Record 588  | pierre
# Processing Record 589  | maloy
# Processing Record 590  | ouegoa
# Processing Record 591  | ruidoso
# Processing Record 592  | fort morgan
# Processing Record 593  | ola
# Processing Record 594  | vitim
# Processing Record 595  | umm ruwabah
# Processing Record 596  | haibowan
# Processing Record 597  | yima
# Processing Record 598  | kitsuki
# Processing Record 599  | hope
# Processing Record 600  | gisborne
# Processing Record 601  | san luis
# Processing Record 602  | preobrazheniye
# Processing Record 603  | vengerovo
# Processing Record 604  | rio claro
# Processing Record 605  | kabelvag
# Processing Record 606  | laiagam
# Processing Record 607  | staryy nadym
# Processing Record 608  | chapais
# Processing Record 609  | kharan
# Processing Record 610  | falealupo
# Processing Record 611  | paamiut
# Processing Record 612  | marsh harbour
# Processing Record 613  | manzil tamim
# Processing Record 614  | husavik
# Processing Record 615  | kuvandyk
# Processing Record 616  | onega
# Processing Record 617  | kutum
# Processing Record 618  | goiatuba
# Processing Record 619  | kabare
# Processing Record 620  | mana
# Processing Record 621  | gornopravdinsk
# Processing Record 622  | rangapara
# Processing Record 623  | bud
# Processing Record 624  | valtice
# Processing Record 625  | livermore

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# cities = [city.capitalize() for city in cities]
city_df = pd.DataFrame(np.array(cities))
city_df.columns =["City"] 
city_df['Cloudiness'] = ""
city_df['Country'] = ""
city_df['Date'] = ""
city_df['Humidity'] = ""
city_df['Lat'] = ""
city_df['Lng'] = ""
city_df['Max Temp'] = ""
city_df['Wind Speed'] = ""
city_df.head()
# Out:
#             City Cloudiness Country Date Humidity Lat Lng Max Temp Wind Speed
# 0    yellowknife
# 1        mataura
# 2       hare bay
# 3  cockburn town
# 4  mar del plata

# %%
for index,row in city_df.iterrows():
    city = row['City']
    query_url = url + "appid=" + api_key + "&q=" + city
    try:
        make_request = requests.get(query_url)
        json_response = make_request.json()
        city_df.loc[index, "Cloudiness"] = json_response["clouds"]["all"]
        city_df.loc[index, "Country"] = json_response["sys"]["country"]
        city_df.loc[index, "Date"] = json_response["dt"]
        city_df.loc[index, "Humidity"] = json_response["main"]["humidity"]
        city_df.loc[index, "Lat"] = json_response["coord"]["lat"]
        city_df.loc[index, "Lng"] = json_response["coord"]["lon"]
        city_df.loc[index, "Max Temp"] = json_response["main"]["temp_max"]
        city_df.loc[index, "Wind Speed"] = json_response["wind"]["speed"]
    except:
        city_df.loc[index, "Cloudiness"] = "NaN"
        city_df.loc[index, "Country"] = "NaN"
        city_df.loc[index, "Date"] = "NaN"
        city_df.loc[index, "Humidity"] = "NaN"
        city_df.loc[index, "Lat"] = "NaN"
        city_df.loc[index, "Lng"] = "NaN"
        city_df.loc[index, "Max Temp"] = "NaN"
        city_df.loc[index, "Wind Speed"] = "NaN"
        continue

city_df.head()
# Out:
#             City Cloudiness Country        Date Humidity    Lat     Lng  \
# 0    yellowknife         75      CA  1553631311       68  62.45 -114.38
# 1        mataura         44      NZ  1553631605       91 -46.19  168.86
# 2       hare bay         40      CA  1553631406       38  48.86  -53.99
# 3  cockburn town         56      TC  1553632084      100  21.46  -71.14
# 4  mar del plata          0      AR  1553632084       40 -46.43  -67.52
#
#   Max Temp Wind Speed
# 0   271.48        6.7
# 1   285.37       5.36
# 2   271.48        8.2
# 3  298.588       3.91
# 4  295.738       2.81

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
print(city_df.count())
print(city_df.dtypes)
# Out:
# City          object
# Cloudiness    object
# Country       object
# Date          object
# Humidity      object
# Lat           object
# Lng           object
# Max Temp      object
# Wind Speed    object
# dtype: object

# %%
cols = ['Cloudiness', 'Humidity', 'Lat','Lng','Max Temp','Wind Speed']
city_df[cols] = city_df[cols].apply(pd.to_numeric, errors='coerce', axis=1)
city_df.dtypes
# Out:
# City           object
# Cloudiness    float64
# Country        object
# Date           object
# Humidity      float64
# Lat           float64
# Lng           float64
# Max Temp      float64
# Wind Speed    float64
# dtype: object

# %%
city_df.plot(kind="scatter", x="Lat", y="Max Temp", marker="o", color="blue", edgecolors="black", grid=True,  title=("City Latitude vs Max Temperature"))

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
city_df.plot(kind="scatter", x="Lat", y="Humidity", marker="o", color="blue", edgecolors="black", grid=True,  title=("City Latitude vs Humidity"))

# %%
city_df.plot(kind="scatter", x="Lat", y="Humidity", marker="o", color="blue", edgecolors="black", grid=True,  title=("City Latitude vs Humidity"))

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
city_df.plot(kind="scatter", x="Lat", y="Cloudiness", marker="o", color="blue", edgecolors="black", grid=True,  title=("City Latitude vs Cloudiness"))

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
city_df.plot(kind="scatter", x="Lat", y="Wind Speed", marker="o", color="blue", edgecolors="black", grid=True,  title=("City Latitude vs Wind Speed"))
